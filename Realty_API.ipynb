# %%
# Standard Imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# Additional Imports
import requests
import json
import os, json, math, time
from tqdm.notebook import tqdm_notebook

# %%
import requests

url = "https://realty-mole-property-api.p.rapidapi.com/properties"

querystring = {"latitude":"33.1507","longitude":"-96.818733","radius":"5","limit":"500"}

headers = {
	"X-RapidAPI-Key": "",
	"X-RapidAPI-Host": "realty-mole-property-api.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

print(response.json())
# Out:
# [{'county': 'Denton', 'propertyType': 'Land', 'lotSize': 89124, 'addressLine1': 'Dallas Pkwy', 'city': 'Frisco', 'state': 'TX', 'zipCode': '75033', 'formattedAddress': 'Dallas Pkwy, Frisco, TX 75033', 'id': 'Dallas-Pkwy,-Frisco,-TX-75033', 'longitude': -96.83999715, 'latitude': 33.18653289}, {'addressLine1': '13024 Dallas Pkwy', 'city': 'Frisco', 'state': 'TX', 'zipCode': '75033', 'formattedAddress': '13024 Dallas Pkwy, Ste 110, Frisco, TX 75033', 'addressLine2': 'Ste 110', 'features': {}, 'county': 'Collin', 'lastSaleDate': '2020-08-14T00:00:00.000Z', 'id': '13024-Dallas-Pkwy,-Ste-110,-Frisco,-TX-75033', 'longitude': -96.83813, 'latitude': 33.18658}, {'addressLine1': '13024 Dallas Pkwy', 'city': 'Frisco', 'state': 'TX', 'zipCode': '75033', 'formattedAddress': '13024 Dallas Pkwy, Ste 120, Frisco, TX 75033', 'addressLine2': 'Ste 120', 'features': {}, 'county': 'Collin', 'lastSaleDate': '2021-10-28T00:00:00.000Z', 'id': '13024-Dallas-Pkwy,-Ste-120,-Frisco,-TX-75033', 'longitude': -96.83813, 'latitude': 33.18658}, {'addressLine1': '13108 Dallas Pkwy', 'city': 'Frisco', 'state': 'TX', 'zipCode': '75033', 'formattedAddress': '13108 Dallas Pkwy, Ste 420, Frisco, TX 75033', 'addressLine2': 'Ste 420', 'features': {}, 'county': 'Collin', 'lastSaleDate': '2020-08-14T00:00:00.000Z', 'id': '13108-Dallas-Pkwy,-Ste-420,-Frisco,-TX-75033', 'longitude': -96.837992, 'latitude': 33.187181}, {'addressLine1': '13080 Dallas Pkwy', 'city': 'Frisco', 'state': 'TX', 'zipCode': '75033', 'formattedAddress': '13080 Dallas Pkwy, Ste 320, Frisco, TX 75033', 'addressLine2': 'Ste 320', 'features': {}, 'county': 'Collin', 'lastSaleDate': '2022-03-01T00:00:00.000Z', 'id': '13080-Dallas-Pkwy,-Ste-320,-Frisco,-TX-75033', 'longitude': -96.83813, 'latitude': 33.186947}, {'addressLine1': '13080 Dallas Pkwy', 'city': 'Frisco', 'state': 'TX', 'zipCode': '75033', 'formattedAddress': '13080 Dallas Pkwy, Ste 310, Frisco, TX 75033', 'addressLine2': 'Ste 310', 'features': {}, 'county': 'Collin', 'lastSaleDate': '2021-05-12T00:00:00.000Z', 'id': '13080-Dallas-Pkwy,-Ste-310,-Frisco,-TX-75033', 'longitude': -96.83813, 'latitude': 33.186947}, {'addressLine1': '13108 Dallas Pkwy', 'city': 'Frisco', 'state': 'TX', 'zipCode': '75033', 'formattedAddress': '13108 Dallas Pkwy, Ste 410, Frisco, TX 75033', 'addressLine2': 'Ste 410', 'features': {}, 'county': 'Collin', 'lastSaleDate': '2020-12-09T00:00:00.000Z', 'id': '13108-Dallas-Pkwy,-Ste-410,-Frisco,-TX-75033', 'longitude': -96.83813, 'latitude': 33.187181}, {'addressLine1': '13108 Dallas Pkwy', 'city': 'Frisco', 'state': 'TX', 'zipCode': '75033', 'formattedAddress': '13108 Dallas Pkwy, Ste 430, Frisco, TX 75033', 'addressLine2': 'Ste 430', 'features': {}, 'county': 'Collin', 'lastSaleDate': '2020-11-06T00:00:00.000Z', 'id': '13108-Dallas-Pkwy,-Ste-430,-Frisco,-TX-75033', 'longitude': -96.83813, 'latitude': 33.187181}, {'addressLine1': '13192 Dallas Pkwy', 'city': 'Frisco', 'state': 'TX', 'zipCode': '75033', 'formattedAddress': '13192 Dallas Pkwy, Ste 610, Frisco, TX 75033', 'addressLine2': 'Ste 610', 'features': {}, 'county': 'Collin', 'lastSaleDate': '2021-02-11T00:00:00.000Z', 'id': '13192-Dallas-Pkwy,-Ste-610,-Frisco,-TX-75033', 'longitude': -96.838101, 'latitude': 33.187542}, {'addressLine1': '13192 Dallas Pkwy', 'city': 'Frisco', 'state': 'TX', 'zipCode': '75033', 'formattedAddress': '13192 Dallas Pkwy, Ste 620, Frisco, TX 75033', 'addressLine2': 'Ste 620', 'features': {}, 'county': 'Collin', 'lastSaleDate': '2020-08-14T00:00:00.000Z', 'id': '13192-Dallas-Pkwy,-Ste-620,-Frisco,-TX-75033', 'longitude': -96.837908, 'latitude': 33.187536}, {'county': 'Collin County', 'bedrooms': 5, 'bathrooms': 4, 'squareFootage': 3805, 'yearBuilt': 2010, 'lotSize': 7405, 'propertyType': 'Single Family', 'addressLine1': '5875 Willoughby', 'city': 'Frisco', 'state': 'TX', 'zipCode': '75033', 'formattedAddress': '5875 Willoughby, Frisco, TX 75033', 'id': '5875-Willoughby,-Frisco,-TX-75033', 'longitude': -96.835253, 'latitude': 33.187901}, {'addr ...

# %%
PropData = response.json()
dfItem = pd.DataFrame(PropData)
dfItem
# Out:
#      county   propertyType  lotSize       addressLine1    city state zipCode  \
# 0    Denton           Land  89124.0        Dallas Pkwy  Frisco    TX   75033
# 1    Collin            NaN      NaN  13024 Dallas Pkwy  Frisco    TX   75033
# 2    Collin            NaN      NaN  13024 Dallas Pkwy  Frisco    TX   75033
# 3    Collin            NaN      NaN  13108 Dallas Pkwy  Frisco    TX   75033
# 4    Collin            NaN      NaN  13080 Dallas Pkwy  Frisco    TX   75033
# ..      ...            ...      ...                ...     ...   ...     ...
# 495  Denton  Single Family   7802.0      4493 Siena Dr  Frisco    TX   75033
# 496  Denton  Single Family   7802.0      4519 Siena Dr  Frisco    TX   75033
# 497  Denton  Single Family   8468.0      4545 Siena Dr  Frisco    TX   75033
# 498  Denton  Single Family   9601.0     4544 Veneto Dr  Frisco    TX   75033
# 499  Denton  Single Family  11953.0     4570 Veneto Dr  Frisco    TX   75033
#
#                                  formattedAddress  \
# 0                   Dallas Pkwy, Frisco, TX 75033
# 1    13024 Dallas Pkwy, Ste 110, Frisco, TX 75033
# 2    13024 Dallas Pkwy, Ste 120, Frisco, TX 75033
# 3    13108 Dallas Pkwy, Ste 420, Frisco, TX 75033
# 4    13080 Dallas Pkwy, Ste 320, Frisco, TX 75033
# ..                                            ...
# 495               4493 Siena Dr, Frisco, TX 75033
# 496               4519 Siena Dr, Frisco, TX 75033
# 497               4545 Siena Dr, Frisco, TX 75033
# 498              4544 Veneto Dr, Frisco, TX 75033
# 499              4570 Veneto Dr, Frisco, TX 75033
#
#                                                id  longitude  ...  \
# 0                   Dallas-Pkwy,-Frisco,-TX-75033 -96.839997  ...
# 1    13024-Dallas-Pkwy,-Ste-110,-Frisco,-TX-75033 -96.838130  ...
# 2    13024-Dallas-Pkwy,-Ste-120,-Frisco,-TX-75033 -96.838130  ...
# 3    13108-Dallas-Pkwy,-Ste-420,-Frisco,-TX-75033 -96.837992  ...
# 4    13080-Dallas-Pkwy,-Ste-320,-Frisco,-TX-75033 -96.838130  ...
# ..                                            ...        ...  ...
# 495               4493-Siena-Dr,-Frisco,-TX-75033 -96.849427  ...
# 496               4519-Siena-Dr,-Frisco,-TX-75033 -96.849207  ...
# 497               4545-Siena-Dr,-Frisco,-TX-75033 -96.848983  ...
# 498              4544-Veneto-Dr,-Frisco,-TX-75033 -96.848982  ...
# 499              4570-Veneto-Dr,-Frisco,-TX-75033 -96.848711  ...
#
#      squareFootage yearBuilt assessorID                legalDescription  \
# 0              NaN       NaN        NaN                             NaN
# 1              NaN       NaN        NaN                             NaN
# 2              NaN       NaN        NaN                             NaN
# 3              NaN       NaN        NaN                             NaN
# 4              NaN       NaN        NaN                             NaN
# ..             ...       ...        ...                             ...
# 495         3210.0    2004.0    R234910  GRIFFIN PARC PH 1 BLK C LOT 13
# 496         3634.0    2005.0    R234911  GRIFFIN PARC PH 1 BLK C LOT 14
# 497         4158.0    2003.0    R234912  GRIFFIN PARC PH 1 BLK C LOT 15
# 498         3992.0    2003.0    R234915  GRIFFIN PARC PH 1 BLK C LOT 18
# 499         2870.0    2002.0    R234914  GRIFFIN PARC PH 1 BLK C LOT 17
#
#            subdivision  ownerOccupied  \
# 0                  NaN            NaN
# 1                  NaN            NaN
# 2                  NaN            NaN
# 3                  NaN            NaN
# 4                  NaN            NaN
# ..                 ...            ...
# 495  GRIFFIN PARC PH 1           True
# 496  GRIFFIN PARC PH 1           True
# 497  GRIFFIN PARC PH 1           True
# 498  GRIFFIN PARC PH 1           True
# 499  GRIFFIN PARC PH 1           True
#
#                                          taxAssessment  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 495  {'2022': {'value': 595177, 'land': 130650, 'im...
# 496  {'2022': {'value': 639415, 'land': 130650, 'im...
# 497  {'2022': {'value': 701702, 'land': 141856, 'im...
# 498  {'2022': {'value': 728104, 'land': 160800, 'im...
# 499  {'2022': {'value': 606739, 'land': 176726, 'im...
#
#                   propertyTaxes  \
# 0                           NaN
# 1                           NaN
# 2                           NaN
# 3                           NaN
# 4                           NaN
# ..                          ...
# 495   {'2022': {'total': 8424}}
# 496  {'2022': {'total': 10534}}
# 497  {'2022': {'total': 11616}}
# 498   {'2022': {'total': 9894}}
# 499   {'2022': {'total': 9923}}
#
#                                                  owner lastSalePrice
# 0                                                  NaN           NaN
# 1                                                  NaN           NaN
# 2                                                  NaN           NaN
# 3                                                  NaN           NaN
# 4                                                  NaN           NaN
# ..                                                 ...           ...
# 495  {'names': ['KLOCKI SPENCER J', 'REBECCA M KLOC...           NaN
# 496  {'names': ['SARAH BETH MICHELLI'], 'mailingAdd...           NaN
# 497  {'names': ['ADOLFO C MOLINAR', 'CLAUDIA S MOLI...           NaN
# 498  {'names': ['DAVID C HAUGLID'], 'mailingAddress...           NaN
# 499  {'names': ['BILL GERTON'], 'mailingAddress': {...           NaN
#
# [500 rows x 26 columns]

# %%
dfItem.to_csv('Prop_Sale_Data_Sample.csv', encoding = 'utf-8-sig', index=False, header=True)
